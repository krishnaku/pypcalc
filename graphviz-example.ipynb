# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext autoreload
# %autoreload 2
import networkx as nx
import importlib
import queuing_network_simulator
import signal_history
import signal_history_metrics

import importlib
importlib.reload(queuing_network_simulator)


G = nx.DiGraph()
G.add_node("A", delay=1)
G.add_node("B", delay=5, concurrency=1)
G.add_node("C", delay=3)

G.add_edge("A", "B", prob=1.0)
G.add_edge("B", "C", prob=1.0)
G.add_edge("B", "A", prob=0.0)  # rework loop
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from queuing_network_simulator import run_simulation

result = run_simulation(G, start_node="A",  T=100, arrival_rate=0.8)

result.get_system_signal_history().queue_length.plot()
result.get_signal_history("A").queue_length.plot()
result.get_signal_history("B").queue_length.plot()
result.get_signal_history("C").queue_length.plot()
# Out:
# <Axes: title={'center': 'C: Queue Length Over Time'}, xlabel='Time', ylabel='L(t)'>
